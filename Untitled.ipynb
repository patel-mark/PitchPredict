# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Fixture_Results.csv')
df.head()
# Out:
#          Home_Team    Away_Team  Home_Score  Away_Score  Home_xG  Away_xG  \
# 0   Manchester Utd       Fulham           1           0      2.4      0.4
# 1     Ipswich Town    Liverpool           0           2      0.5      2.6
# 2    Newcastle Utd  Southampton           1           0      0.3      1.8
# 3          Everton     Brighton           0           3      0.5      1.4
# 4  Nott'ham Forest  Bournemouth           1           1      1.3      1.2
#
#            League
# 0  Premier League
# 1  Premier League
# 2  Premier League
# 3  Premier League
# 4  Premier League

# %%
df.isnull().sum()
# Out:
# Home_Team     0
# Away_Team     0
# Home_Score    0
# Away_Score    0
# Home_xG       1
# Away_xG       1
# League        0
# dtype: int64
