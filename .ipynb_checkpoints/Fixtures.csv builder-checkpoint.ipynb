# %%
import pandas as pd

# %%
df=pd.read_csv('Combined_Leagues_Stats.csv')

df['team'].unique()
# Out:
# array(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton',
#        'Chelsea', 'Crystal Palace', 'Everton', 'Fulham', 'Ipswich Town',
#        'Leicester City', 'Liverpool', 'Manchester City', 'Manchester Utd',
#        'Newcastle Utd', "Nott'ham Forest", 'Southampton', 'Tottenham',
#        'West Ham', 'Wolves', 'Atalanta', 'Bologna', 'Cagliari', 'Como',
#        'Empoli', 'Fiorentina', 'Genoa', 'Hellas Verona', 'Inter',
#        'Juventus', 'Lazio', 'Lecce', 'Milan', 'Monza', 'Napoli', 'Parma',
#        'Roma', 'Torino', 'Udinese', 'Venezia', 'Augsburg',
#        'Bayern Munich', 'Bochum', 'Dortmund', 'Eint Frankfurt',
#        'Freiburg', 'Gladbach', 'Heidenheim', 'Hoffenheim',
#        'Holstein Kiel', 'Leverkusen', 'Mainz 05', 'RB Leipzig',
#        'St. Pauli', 'Stuttgart', 'Union Berlin', 'Werder Bremen',
#        'Wolfsburg', 'Angers', 'Auxerre', 'Brest', 'Le Havre', 'Lens',
#        'Lille', 'Lyon', 'Marseille', 'Monaco', 'Montpellier', 'Nantes',
# ...

# %%
fixed_content = '''Home_Team,Away_Team
Everton,Manchester Utd
Arsenal,West Ham
Bournemouth,Wolves
Fulham,Crystal Palace
Ipswich Town,Tottenham
Southampton,Brighton
Aston Villa,Chelsea
Alavés,Espanyol
Rayo Vallecano,Villarreal
Valencia,Atlético Madrid
Las Palmas,Barcelona
Gladbach,Augsburg
Holstein Kiel,Leverkusen
Mainz 05,St. Pauli
Wolfsburg,Bochum
Dortmund,Union Berlin
Parma,Bologna
Venezia,Lazio
Torino,Milan
Inter,Genoa
Lille,Monaco
Saint-Étienne,Angers
Auxerre,Marseille
Derby County,Millwall
Plymouth Argyle,Cardiff City
Sunderland,Hull City
Coventry City,Preston
Norwich City,Stoke City
Portsmouth,QPR
Swansea City,Blackburn
West Brom,Oxford United
Reggiana,Carrarese
Cittadella,Modena
Mantova,Bari
Pisa,Juve Stabia
Cremonese,Cesena
'''.replace('й', 'é')

with open('fixtures.csv', 'w', encoding='utf-8') as f:
    f.write(fixed_content)
